# %%
import os
import time
import requests
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
import numpy as np
from numpy.linalg import norm
from tqdm import tqdm
import pickle
from flask import Flask, jsonify, request, send_from_directory
from flask_cors import CORS
from selenium import webdriver
from selenium.webdriver import ChromeOptions, Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import StaleElementReferenceException, TimeoutException, NoSuchElementException
from sklearn.neighbors import NearestNeighbors
import cv2
import base64
import re
from PIL import Image
from io import BytesIO

app = Flask(__name__)
CORS(app)

IMAGE_FOLDER = 'downloaded_images'
if not os.path.exists(IMAGE_FOLDER):
    os.makedirs(IMAGE_FOLDER)



resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
resnet_model.trainable = False
resnet_model = tf.keras.Sequential([
    resnet_model,
    GlobalMaxPooling2D()
])

def fetch_image_urls(driver, css_selector, retry_count=3):
    for attempt in range(retry_count):
        try:
            image_elements = WebDriverWait(driver, 20).until(
                EC.presence_of_all_elements_located((By.CSS_SELECTOR, css_selector))
            )
            return [image.get_attribute('src') for image in image_elements]
        except (StaleElementReferenceException, TimeoutException, NoSuchElementException) as e:
            if attempt < retry_count - 1:
                print(f"{e} encountered. Retrying... (Attempt {attempt + 1})")
            else:
                raise

def download_images(image_urls):
    local_image_urls = []
    base64_pattern = re.compile(r'^data:image/(?P<ext>.+?);base64,(?P<data>.+)')
    index = 0  

    for url in image_urls:
        try:
            match = base64_pattern.match(url)
            if match:
                ext = match.group('ext')
                data = match.group('data')
                if ext.lower() == 'gif':
                    print(f"Skipping base64 GIF image at index {index}")
                    continue

                print(f"Processing base64 image at index {index}")
                img_data = base64.b64decode(data)
                image_path = os.path.join(IMAGE_FOLDER, f'image_{index}.{ext}')
                
            
                image = Image.open(BytesIO(img_data))
                image.save(image_path)
                
                local_image_urls.append(image_path)
                index += 1 
            else:
                response = requests.get(url)
                if response.status_code == 200:
                    if 'image/gif' in response.headers.get('content-type'):
                        print(f"Skipping GIF image from URL: {url}")
                        continue

                    print(f"Downloading image from {url}")
                    image_path = os.path.join(IMAGE_FOLDER, f'image_{index}.jpg')
                    with open(image_path, 'wb') as f:
                        f.write(response.content)
                    local_image_urls.append(image_path)
                    index += 1  
                else:
                    print(f"Failed to download image from {url}")
        except Exception as e:
            print(f"Error processing image at index {index}: {e}")
    
    return local_image_urls


def extract_features(img_path, resnet_model):
    img = cv2.imread(img_path)
    img_array = cv2.resize(img, (224, 224))
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    
    result = resnet_model.predict(preprocessed_img).flatten()
    normalized_result = result / norm(result)
    
    return normalized_result





@app.route('/', methods=['POST'])
def newp():
    feature_list = np.array(pickle.load(open('embeddings.pkl', 'rb')))
    filenames = pickle.load(open('filenames.pkl', 'rb'))
    data = request.json
    index = data["index"]
    img_path = None
    
   
    for ext in ['jpg', 'jpeg', 'png']:
        potential_path = f'downloaded_images/image_{index}.{ext}'
        if os.path.exists(potential_path):
            img_path = potential_path
            break
    
    if not img_path:
        return jsonify({"error": "Image not found"}), 404

    features = extract_features(img_path, resnet_model)
    if features is None:
        return jsonify({"error": "Failed to extract features from image"}), 500

    n_neighbors = min(4, len(feature_list))  
    neighbors = NearestNeighbors(n_neighbors=n_neighbors, algorithm='brute', metric='euclidean')
    neighbors.fit(feature_list)

    distances, indices = neighbors.kneighbors([features])

    similar_images = [f"image_{filenames[file].split('_')[-1].split('.')[0]}" for file in indices[0][0:n_neighbors]]

    return jsonify({"similar_images": similar_images})

@app.route('/fetch-images', methods=['POST'])
def fetch_images():
    data = request.get_json()
    usertag = data.get('usertag')
    if not usertag:
        return jsonify({"error": "No tag provided"}), 400

    options = ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--disable-infobars")
    options.add_argument("--disable-extensions")
    options.add_argument("--disable-gpu")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_experimental_option("excludeSwitches", ["enable-automation"])

    driver = webdriver.Chrome(options=options)
    url = "https://www.instagram.com/"
    driver.get(url)

    username = WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'input[name="username"]')))
    username.send_keys('instrumental_freaakk')
    username.send_keys(Keys.ENTER)

    password = WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, 'input[name="password"]')))
    password.send_keys('demonlord')
    password.send_keys(Keys.ENTER)

    time.sleep(10)

    explore_url = f"https://www.instagram.com/explore/tags/{usertag}/"
    driver.get(explore_url)

    time.sleep(5)

    instagram_image_urls = fetch_image_urls(driver, 'img[class="x5yr21d xu96u03 x10l6tqk x13vifvy x87ps6o xh8yej3"][crossorigin="anonymous"]')
    print(f"Instagram image URLs: {instagram_image_urls}")

    driver.quit()

    

    

    driver = webdriver.Chrome(options=options)
    news_url = f"https://www.google.com/search?q={usertag}+trending&tbm=isch"
    driver.get(news_url)

    time.sleep(5)
    

    news_image_urls = fetch_image_urls(driver, 'img[class="rg_i Q4LuWd"],img[class="YQ4gaf"]')
    print(f"News image URLs: {news_image_urls}")
    driver.quit()

    combined_image_urls = news_image_urls+instagram_image_urls
    print(f"Combined image URLs: {combined_image_urls}")

    local_image_urls = download_images(combined_image_urls)
    
  

    return jsonify({"result": "success", "urls": local_image_urls})

@app.route('/images/<filename>')
def serve_image(filename):
    return send_from_directory(IMAGE_FOLDER, filename)

if __name__ == '__main__':
    print("Server started")
    from werkzeug.serving import run_simple
    run_simple('localhost', 5000, app)
# Out:
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5000
# Press CTRL+C to quit
# Server started
# 127.0.0.1 - - [11/Jul/2024 16:09:45] "OPTIONS /fetch-images HTTP/1.1" 200 -
# Instagram image URLs: ['https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/449097202_490689816779160_3702800054234264753_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=A2A2Y9T-YLwQ7kNvgFh6rWP&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzM5ODU0ODkyMTM0NjMwMDk0Mw%3D%3D.2-ccb7-5&oh=00_AYCX1000fKGnD3hX7E9hKP15Qh6QBkVm63ziHIuuNd8Y_A&oe=6695890E&_nc_sid=2011ad', 'https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/447769382_740791584671159_6321492072163461079_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMTcweDExNzAuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=E3OVY9yc9DQQ7kNvgEiuNG6&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzM4NTg0NzUyMzE5NDE4NDczMw%3D%3D.2-ccb7-5&oh=00_AYBdAGW5fqeFrqrnMFW9YPfUD3i2YLjANFRQ1oBkzQNwig&oe=66958737&_nc_sid=2011ad', 'https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/450640401_7551570674952079_3368164433583371187_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMTA3eDExMDcuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=100ZFQuwafEQ7kNvgF-t279&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzQwOTU2NDgyMjQ3MzM0NjYyOA%3D%3D.2-ccb7-5&oh=00_AYB-X2ZYbBZiUAylvXCPz13J6c5bfSh3rZBbBX29eEkxyQ&oe=66957DEC&_nc_sid=2011ad', 'https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/
://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/450640401_7551570674952079_3368164433583371187_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMTA3eDExMDcuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=100ZFQuwafEQ7kNvgF-t279&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzQwOTU2NDgyMjQ3MzM0NjYyOA%3D%3D.2-ccb7-5&oh=00_AYB-X2ZYbBZiUAylvXCPz13J6c5bfSh3rZBbBX29eEkxyQ&oe=66957DEC&_nc_sid=2011ad', 'https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/450395493_494653143098316_3401730991941682927_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMzQ0eDE2NzEuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=cTr9HkQEZMwQ7kNvgH50t36&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzQwOTAwMTEwOTIzMjcwMjA5Mg%3D%3D.2-ccb7-5&oh=00_AYCboZu57R1fU5P0tTLD0tBknlRMk5_MEILIOHVo7m6iVA&oe=66958872&_nc_sid=2011ad', 'https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/450545886_1619718598876099_9021995344835763342_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMTc5eDExNjUuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=st9SBJ6gnGIQ7kNvgGW19NR&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzQwOTA0OTA5MzM0NTQ4MjA2NA%3D%3D.2-ccb7-5&oh=00_AYDIXJPPF27F7SCW6CS8j82p-VmdNaVexYP7IAwl8IQVUg&oe=66956D5A&_nc_sid=2011ad', 'https://instagram.fstv8-2.fna.fbcdn.net/v/t51.29350-15/450417608_390131496919073_3921006273999054523_n.jpg?stp=dst-jpg_e15&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi40ODB4ODU0LnNkci5mMjkzNTAifQ&_nc_ht=instagram.fstv8-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=ogNSzrw4FDsQ7kNvgGij73-&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzQwNzkzOTExMTIyNTMxMTAwMg%3D%3D.2-ccb7-5&oh=00_AYCOq1eBMWzDmKzBikzpbF ...
# Processing base64 image at index 0
# Processing base64 image at index 1
# Processing base64 image at index 2
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSGyjMMiskbJeuGDMGPffSjEfMUFKg9LdDfbw&s
# Processing base64 image at index 4
# Processing base64 image at index 5
# Processing base64 image at index 6
# Processing base64 image at index 7
# Processing base64 image at index 8
# Processing base64 image at index 9
# Processing base64 image at index 10
# Processing base64 image at index 11
# Processing base64 image at index 12
# Processing base64 image at index 13
# Processing base64 image at index 14
# Processing base64 image at index 15
# Processing base64 image at index 16
# Processing base64 image at index 17
# Processing base64 image at index 18
# Processing base64 image at index 19
# Processing base64 image at index 20
# Processing base64 image at index 21
# Processing base64 image at index 22
# Processing base64 image at index 23
# Processing base64 image at index 24
# Processing base64 image at index 25
# Processing base64 image at index 26
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Skipping base64 GIF image at index 27
# Downloading image from https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/449097202_490689816779160_3702800054234264753_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=A2A2Y9T-YLwQ7kNvgFh6rWP&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzM5ODU0ODkyMTM0NjMwMDk0Mw%3D%3D.2-ccb7-5&oh=00_AYCX1000fKGnD3hX7E9hKP15Qh6QBkVm63ziHIuuNd8Y_A&oe=6695890E&_nc_sid=2011ad
# Downloading image from https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/447769382_740791584671159_6321492072163461079_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMTcweDExNzAuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=E3OVY9yc9DQQ7kNvgEiuNG6&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzM4NTg0NzUyMzE5NDE4NDczMw%3D%3D.2-ccb7-5&oh=00_AYBdAGW5fqeFrqrnMFW9YPfUD3i2YLjANFRQ1oBkzQNwig&oe=66958737&_nc_sid=2011ad
# Downloading image from https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/450640401_7551570674952079_3368164433583371187_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMTA3eDExMDcuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=100ZFQuwafEQ7kNvgF-t279&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzQwOTU2NDgyMjQ3MzM0NjYyOA%3D%3D.2-ccb7-5&oh=00_AYB-X2ZYbBZiUAylvXCPz13J6c5bfSh3rZBbBX29eEkxyQ&oe=66957DEC&_nc_sid=2011ad
# Downloading image from https://instagram.fstv8-1.fna.fbcdn.net/v/t51.29350-15/450395493_494653143098316_3401730991941682927_n.jpg?stp=dst-jpg_e35&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMzQ0eDE2NzEuc2RyLmYyOTM1MCJ9&_nc_ht=instagram.fstv8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=cTr9HkQEZMwQ7kNvgH50t36&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzQwO
s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR27TnXKJO7hlPxYLaNK4HHmfHx0PSbNbUL6g&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQp6pxRMEyoTuFlmOyAKQvvxyUmhNf2vwYUYQ&s', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRy0HSKViVNmr76wzLEg5SbjyqFeZW0p_pngw&s', '...', '...', '...', '...', '...', '...', '...', '...', '...', '.. ...
# Processing base64 image at index 0
# Processing base64 image at index 1
# Processing base64 image at index 2
# Processing base64 image at index 3
# Processing base64 image at index 4
# Processing base64 image at index 5
# Processing base64 image at index 6
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQCcQ7gkv90ho9UJotO_6YXMNnVUTIcPppfnA&s
# Processing base64 image at index 8
# Processing base64 image at index 9
# Processing base64 image at index 10
# Processing base64 image at index 11
# Processing base64 image at index 12
# Processing base64 image at index 13
# Processing base64 image at index 14
# Processing base64 image at index 15
# Processing base64 image at index 16
# Processing base64 image at index 17
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR6MNRVrZx-0pAfNp4qtLNWv4jOZiGduulhcQ&s
# Processing base64 image at index 19
# Processing base64 image at index 20
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQPfd106ocPgCug7nH1OHo6oBj-2sA3I-xZPw&s
# Processing base64 image at index 22
# Processing base64 image at index 23
# Processing base64 image at index 24
# Processing base64 image at index 25
# Processing base64 image at index 26
# Processing base64 image at index 27
# Processing base64 image at index 28
# Processing base64 image at index 29
# Processing base64 image at index 30
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcStLlN1g-YkH_-sIt49AUpZX6HfBw6-ZSpNyg&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTzGh8ZD8KZHBZlyUCa29IQiqM5a29g_jHPEg&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQf5ZBX_np3u65IafyRX_NE0hDT4CI2MHFFjg&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQjjza7eg6KSPulTlmATHsdxxFDNIo0CWJL2g&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRCohIzxfOicr_-JTWfypNsvgiRvNSvR2pAjA&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-8VQVk7Ob0AS4_ytuKHw_jVNe45af_DlYIA&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQbjnHlU1ydZkshJwsaiU1gePSTrrD6C_RPnw&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-zQSOyDliQIqkzpFJN30TelzblKti4os-Ig&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRJFZnO0-hl0vWP179THk5iJT0tpOYLvsH16w&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRkPSKjdZQhWv2nV0lvmECqS4JryoiJ9Q5twA&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1SWq2APRyoCqjt6U3VVcxlKZKoW8DH7FGbA&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQPRriR-G9GG4VSl1ZUIMZDNCdft2rxzaLZuA&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTrkmh_I9rpgD9vbGEsMDj3aM97iOkC1YVAAw&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTWHfy1E2h-CaBh6UWzBC9t_R78jtXYZwDKAg&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRcLL0fXxDYJzhYrKBND5rLAukr5L7zPwOC6g&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFkhNrrWfFaLg1nXdqkiaAGjt233TrOnBo4w&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8KpwNPMzYRwBvv9cSjp7bHw4r04nSey-t3g&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgy_bHj5tsc-eldKJx0NOlaabLb6B2zyYGIw&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ4ffM3FuIXnl4cVRKdGDpKT_6vSpOZCglLIg&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTKqn3u4JefLRDgoO2CjItAsEa1h_CX10SnmA&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTHc5J3V1nHiKz-7rcQNvLQMHIsY3rocqjSzg&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQBwXLwUWpXajwkXld1M-8Gj-ZL2COqoTFbyg&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRiC1ME5n6e1c0C5fm4oynyJNgxSxub0uhx5A&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTejmqi6qG1OBfoo11I-YQJJAgj20hUfpxlwQ&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTqFczGZZmvMk6DiEHO_B3ieYZnWYSUFBUlSA&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjfW5H9FZncv1amm_aoBZ5DTOnJxKnN7uSmg&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR27TnXKJO7hlPxYLaNK4HHmfHx0PSbNbUL6g&s
# Downloading image from https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9Gc